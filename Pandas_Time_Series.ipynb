# %%
print("maa Kali")
# Out:
# maa Kali

# %%
print('Jai Maa Kali')
# Out:
# Jai Maa Kali

# %%
import pandas as pd

# %%
x=pd.read_csv('aapl.csv',parse_dates=['Date'])
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_14244\743962986.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   x=pd.read_csv('aapl.csv',parse_dates=['Date'])

# %%
x
# Out:
#           Date    Open    High     Low   Close    Volume
# 0   2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1   2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2   2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3   2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4   2017-06-30  144.45  144.96  143.78  144.02  23024107
# ..         ...     ...     ...     ...     ...       ...
# 246 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 247 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 248 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 249 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 250 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 6 columns]

# %%
type(x['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
print("Jai Maa Kali")
# Out:
# Jai Maa Kali

# %%
print("Jai Maa Kali")
# Out:
# Jai Maa Kali

# %%
import pandas as pd

# %%
import numpy as np

# %%
x=pd.read_csv("aapl.csv",parse_dates=['Date'],index_col='Date')
#parse dates converts the Date Column into Proper Date-TIme FOrmat COlumn
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_7488\329321562.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   x=pd.read_csv("aapl.csv",parse_dates=['Date'],index_col='Date')

# %%
x
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
#type(x['Date'][0])

# %%
#x['Date']=pd.to_datetime(x['Date'])

# %%
#x.set_index('Date',append=True,inplace=True)

# %%
x
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
x.loc['2016-07-11']
# Out:
# Open            96.75
# High            97.65
# Low             96.73
# Close           96.98
# Volume    23794945.00
# Name: 2016-07-11 00:00:00, dtype: float64

# %%
x.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
x.loc['2017-01'].head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673

# %%
x.sort_index().loc['2017-06'].Close.mean()
# Out:
# 147.83136363636365

# %%
x.sort_index().loc['2017-07-03':'2017-07-07']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712

# %%
x.sort_index(inplace=True)

# %%
x
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# ...            ...     ...     ...     ...       ...
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
#
# [251 rows x 5 columns]

# %%
x.loc['2017-07-03':'2017-07-07']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712

# %%
x['Close'].resample('M').mean()
#checking month wise stock for that i used resample month wise
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline

# %%
x['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
x["Close"].resample('M').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
x=pd.read_csv('hey.csv')

# %%
x.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715
# 2  154.34  154.45  153.46  153.93  25331662
# 3  153.90  155.81  153.78  154.45  26624926
# 4  155.02  155.98  154.48  155.37  21069647

# %%
range=pd.date_range(start="6/1/2016",end="6/30/2016",freq='B')

# %%
range
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-06',
#                '2016-06-07', '2016-06-08', '2016-06-09', '2016-06-10',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-20', '2016-06-21', '2016-06-22',
#                '2016-06-23', '2016-06-24', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
x.set_index(range,inplace=True)

# %%
x
# Out:
#               Open    High     Low   Close    Volume
# 2016-06-01  153.17  153.33  152.22  153.18  16404088
# 2016-06-02  153.58  155.45  152.89  155.45  27770715
# 2016-06-03  154.34  154.45  153.46  153.93  25331662
# 2016-06-06  153.90  155.81  153.78  154.45  26624926
# 2016-06-07  155.02  155.98  154.48  155.37  21069647
# 2016-06-08  155.25  155.54  154.40  154.99  21250798
# 2016-06-09  155.19  155.19  146.02  148.98  64882657
# 2016-06-10  145.74  146.09  142.51  145.42  72307330
# 2016-06-13  147.16  147.45  145.15  146.59  34165445
# 2016-06-14  147.50  147.50  143.84  145.16  31531232
# 2016-06-15  143.32  144.48  142.21  144.29  32165373
# 2016-06-16  143.78  144.50  142.20  142.27  50361093
# 2016-06-17  143.66  146.74  143.66  146.34  32541404
# 2016-06-20  146.87  146.87  144.94  145.01  24900073
# 2016-06-21  145.52  146.07  144.61  145.87  21265751
# 2016-06-22  145.77  146.70  145.12  145.63  19106294
# 2016-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
y=pd.date_range(start="6/1/2016",end="6/30/2016",freq='D')

# %%
y
# Out:
# DatetimeIndex(['2016-06-01', '2016-06-02', '2016-06-03', '2016-06-04',
#                '2016-06-05', '2016-06-06', '2016-06-07', '2016-06-08',
#                '2016-06-09', '2016-06-10', '2016-06-11', '2016-06-12',
#                '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16',
#                '2016-06-17', '2016-06-18', '2016-06-19', '2016-06-20',
#                '2016-06-21', '2016-06-22', '2016-06-23', '2016-06-24',
#                '2016-06-25', '2016-06-26', '2016-06-27', '2016-06-28',
#                '2016-06-29', '2016-06-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
y.difference(range)
# Out:
# DatetimeIndex(['2016-06-04', '2016-06-05', '2016-06-11', '2016-06-12',
#                '2016-06-18', '2016-06-19', '2016-06-25', '2016-06-26'],
#               dtype='datetime64[ns]', freq=None)

# %%
# %matplotlib inline

# %%
x.Close.plot()
# Out:
# <Axes: >

# %%
#padding mehtod takes the previous records for the holidays
x.asfreq('D',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2016-06-01  153.17  153.33  152.22  153.18  16404088
# 2016-06-02  153.58  155.45  152.89  155.45  27770715
# 2016-06-03  154.34  154.45  153.46  153.93  25331662
# 2016-06-04  154.34  154.45  153.46  153.93  25331662
# 2016-06-05  154.34  154.45  153.46  153.93  25331662
# 2016-06-06  153.90  155.81  153.78  154.45  26624926
# 2016-06-07  155.02  155.98  154.48  155.37  21069647
# 2016-06-08  155.25  155.54  154.40  154.99  21250798
# 2016-06-09  155.19  155.19  146.02  148.98  64882657
# 2016-06-10  145.74  146.09  142.51  145.42  72307330
# 2016-06-11  145.74  146.09  142.51  145.42  72307330
# 2016-06-12  145.74  146.09  142.51  145.42  72307330
# 2016-06-13  147.16  147.45  145.15  146.59  34165445
# 2016-06-14  147.50  147.50  143.84  145.16  31531232
# 2016-06-15  143.32  144.48  142.21  144.29  32165373
# 2016-06-16  143.78  144.50  142.20  142.27  50361093
# 2016-06-17  143.66  146.74  143.66  146.34  32541404
# ...

# %%
x.asfreq('W',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2016-06-05  154.34  154.45  153.46  153.93  25331662
# 2016-06-12  145.74  146.09  142.51  145.42  72307330
# 2016-06-19  143.66  146.74  143.66  146.34  32541404
# 2016-06-26  147.17  148.28  145.38  145.82  25692361

# %%
range=pd.date_range('1/1/2011',periods=30,freq='H')

# %%
range
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                '2011-01-01 10:00:00', '2011-01-01 11:00:00',
#                '2011-01-01 12:00:00', '2011-01-01 13:00:00',
#                '2011-01-01 14:00:00', '2011-01-01 15:00:00',
#                '2011-01-01 16:00:00', '2011-01-01 17:00:00',
#                '2011-01-01 18:00:00', '2011-01-01 19:00:00',
#                '2011-01-01 20:00:00', '2011-01-01 21:00:00',
#                '2011-01-01 22:00:00', '2011-01-01 23:00:00',
#                '2011-01-02 00:00:00', '2011-01-02 01:00:00',
#                '2011-01-02 02:00:00', '2011-01-02 03:00:00',
#                '2011-01-02 04:00:00', '2011-01-02 05:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
import numpy as np

# %%
z=pd.Series(np.random.randint(0,10,len(range)),index=range)

# %%
z
# Out:
# 2011-01-01 00:00:00    7
# 2011-01-01 01:00:00    1
# 2011-01-01 02:00:00    9
# 2011-01-01 03:00:00    9
# 2011-01-01 04:00:00    3
# 2011-01-01 05:00:00    1
# 2011-01-01 06:00:00    3
# 2011-01-01 07:00:00    1
# 2011-01-01 08:00:00    6
# 2011-01-01 09:00:00    2
# 2011-01-01 10:00:00    7
# 2011-01-01 11:00:00    8
# 2011-01-01 12:00:00    6
# 2011-01-01 13:00:00    7
# 2011-01-01 14:00:00    7
# 2011-01-01 15:00:00    8
# 2011-01-01 16:00:00    9
# 2011-01-01 17:00:00    4
# 2011-01-01 18:00:00    8
# 2011-01-01 19:00:00    8
# 2011-01-01 20:00:00    6
# 2011-01-01 21:00:00    7
# 2011-01-01 22:00:00    6
# 2011-01-01 23:00:00    2
# 2011-01-02 00:00:00    8
# 2011-01-02 01:00:00    5
# 2011-01-02 02:00:00    5
# 2011-01-02 03:00:00    3
# 2011-01-02 04:00:00    5
# 2011-01-02 05:00:00    9
# Freq: H, dtype: int32

# %%
x
# Out:
#               Open    High     Low   Close    Volume
# 2016-06-01  153.17  153.33  152.22  153.18  16404088
# 2016-06-02  153.58  155.45  152.89  155.45  27770715
# 2016-06-03  154.34  154.45  153.46  153.93  25331662
# 2016-06-06  153.90  155.81  153.78  154.45  26624926
# 2016-06-07  155.02  155.98  154.48  155.37  21069647
# 2016-06-08  155.25  155.54  154.40  154.99  21250798
# 2016-06-09  155.19  155.19  146.02  148.98  64882657
# 2016-06-10  145.74  146.09  142.51  145.42  72307330
# 2016-06-13  147.16  147.45  145.15  146.59  34165445
# 2016-06-14  147.50  147.50  143.84  145.16  31531232
# 2016-06-15  143.32  144.48  142.21  144.29  32165373
# 2016-06-16  143.78  144.50  142.20  142.27  50361093
# 2016-06-17  143.66  146.74  143.66  146.34  32541404
# 2016-06-20  146.87  146.87  144.94  145.01  24900073
# 2016-06-21  145.52  146.07  144.61  145.87  21265751
# 2016-06-22  145.77  146.70  145.12  145.63  19106294
# 2016-06-23  145.13  147.16  145.11  146.28  35439389
# ...
