# %%
print('Jai Maa Kali,love you Shiromani')
# Out:
# Jai Maa Kali,love you Shiromani

# %%
print('Jai Maa Kali')
# Out:
# Jai Maa Kali

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('C:\\Users\\barad\\Downloads\\nyc_weather.csv')

# %%
df.head(2)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain' ]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.8+ KB

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# EST                     0
# Temperature             0
# DewPoint                0
# Humidity                0
# Sea Level PressureIn    0
# VisibilityMiles         0
# WindSpeedMPH            0
# PrecipitationIn         0
# CloudCover              0
# Events                  0
# WindDirDegrees          0
# dtype: int64

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %%
x=pd.DataFrame({'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']})

# %%
x.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
x.shape
# Out:
# (6, 4)

# %%
x
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df=x

# %%
df.shape
# Out:
# (6, 4)

# %%
df[1:3]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df[0::]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[1:]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df['day'].min()
# Out:
# '1/1/2017'

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['day', 'temperature', 'windspeed']]
# Out:
#         day  temperature  windspeed
# 0  1/1/2017           32          6
# 1  1/2/2017           35          7
# 2  1/3/2017           28          2
# 3  1/4/2017           24          7
# 4  1/5/2017           32          4
# 5  1/6/2017           31          2

# %%
df['day'][df['temperature']==df['temperature'].max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df[df['temperature']>32]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df['event'].min()
# Out:
# 'Rain'

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df.set_index('event',inplace=True)

# %%
df.head()
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.index
# Out:
# Index(['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'], dtype='object', name='day')

# %%
df.tail(2)
# Out:
#        temperature  windspeed
# event
# Rain            32          4
# Sunny           31          2

# %%
df.loc['Snow']
# Out:
#        temperature  windspeed
# event
# Snow            28          2
# Snow            24          7

# %%
print('Jai Maa Kali')
# Out:
# Jai Maa Kali

# %%
import pandas as pd
# Out:
# C:\Users\barad\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_excel('C:\\Users\\barad\\Downloads\\weather_data.xlsx','Sheet1')

# %%
pip uninstall openpyxl

# %%
df.head()

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
x=[(1,'hey'),(2,'a'),(3,'c')]

# %%
x
# Out:
# [(1, 'hey'), (2, 'a'), (3, 'c')]

# %%
type(x)
# Out:
# list

# %%
pd.DataFrame(x,columns=['rno','name'])
# Out:
#    rno name
# 0    1  hey
# 1    2    a
# 2    3    c

# %%
df=pd.read_csv('C:\\Users\\barad\\Downloads\\stock_data.csv',na_values=['n.a.','not available',-1])

# %%
df.head()
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT    NaN     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df=pd.read_csv('C:\\Users\\barad\\Downloads\\stock_data.csv')

# %%
df.head()
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df.isnull().sum()
# Out:
# tickers    0
# eps        0
# revenue    0
# price      0
# people     0
# dtype: int64

# %%
df.to_csv('hey.csv',header=0)

# %%
df.to_csv("hey",header=False)

# %%
df.to_excel('new.xlsx',index=False)

# %%
df.head()
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def fun(cell):
    if cell=='n.a.' or cell=='not available':
        return 'hey'
    return cell

# %%
df=pd.read_csv('C:\\Users\\barad\\Downloads\\stock_data.csv',converters={'people':fun,'eps':fun})

# %%
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82       87   845     larry page
# 1     WMT   4.61      484    65            hey
# 2    MSFT     -1       85    64     bill gates
# 3    RIL     hey       50  1023  mukesh ambani
# 4    TATA    5.6       -1  n.a.     ratan tata

# %%
x = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

y =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('hey.xlsx') as hey:

    y.to_excel(hey,sheet_name='1')
    x.to_excel(hey,sheet_name='2')

# %% [markdown]
# # clubbing to excel files into a single sheet

# %%
#see up

# %%
print("Jai Maa Kali")
# Out:
# Jai Maa Kali

# %%
import pandas as pd

# %%
x=pd.read_csv('C:\\Users\\barad\\Downloads\\weather_data.csv')

# %%
x.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/4/2017          NaN        9.0  Sunny
# 2  1/5/2017         28.0        NaN   Snow
# 3  1/6/2017          NaN        7.0    NaN
# 4  1/7/2017         32.0        NaN   Rain

# %%
type(x.windspeed[0])
# Out:
# numpy.float64

# %%
x.set_index('day',inplace=True)

# %%
x.head(1)
# Out:
#           temperature  windspeed event
# day
# 1/1/2017         32.0        6.0  Rain

# %%
y=x.fillna(0)

# %%
y
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           0.0        9.0   Sunny
# 1/5/2017          28.0        0.0    Snow
# 1/6/2017           0.0        7.0       0
# 1/7/2017          32.0        0.0    Rain
# 1/8/2017           0.0        0.0   Sunny
# 1/9/2017           0.0        0.0       0
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
z=x.fillna({'temperature':0,'windspeed':0,'event':'Nope'})

# %%
z
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           0.0        9.0   Sunny
# 1/5/2017          28.0        0.0    Snow
# 1/6/2017           0.0        7.0    Nope
# 1/7/2017          32.0        0.0    Rain
# 1/8/2017           0.0        0.0   Sunny
# 1/9/2017           0.0        0.0    Nope
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x.ffill()
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        9.0    Snow
# 1/6/2017          28.0        7.0    Snow
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017          32.0        7.0   Sunny
# 1/9/2017          32.0        7.0   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x.bfill()
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          28.0        9.0   Sunny
# 1/5/2017          28.0        7.0    Snow
# 1/6/2017          32.0        7.0    Rain
# 1/7/2017          32.0        8.0    Rain
# 1/8/2017          34.0        8.0   Sunny
# 1/9/2017          34.0        8.0  Cloudy
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df = x.fillna(method="ffill", axis="columns") # axis is either "index" or "columns"
new_df
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_4284\3334262280.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = x.fillna(method="ffill", axis="columns") # axis is either "index" or "columns"
#           temperature windspeed   event
# day
# 1/1/2017         32.0       6.0    Rain
# 1/4/2017          NaN       9.0   Sunny
# 1/5/2017         28.0      28.0    Snow
# 1/6/2017          NaN       7.0     7.0
# 1/7/2017         32.0      32.0    Rain
# 1/8/2017          NaN       NaN   Sunny
# 1/9/2017          NaN       NaN     NaN
# 1/10/2017        34.0       8.0  Cloudy
# 1/11/2017        40.0      12.0   Sunny

# %%
new_df = x.fillna(method="ffill",limit=1)
new_df
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_4284\422924112.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = x.fillna(method="ffill",limit=1)
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        9.0    Snow
# 1/6/2017          28.0        7.0    Snow
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017          32.0        NaN   Sunny
# 1/9/2017           NaN        NaN   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x.fillna(method='ffill',limit=2)
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_4284\400384251.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   x.fillna(method='ffill',limit=2)
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017          32.0        9.0   Sunny
# 1/5/2017          28.0        9.0    Snow
# 1/6/2017          28.0        7.0    Snow
# 1/7/2017          32.0        7.0    Rain
# 1/8/2017          32.0        7.0   Sunny
# 1/9/2017          32.0        NaN   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
new_df = x.interpolate(method='time') 
new_df
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_4284\1047709022.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = x.interpolate(method='time')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 new_df = x.interpolate(method='time')
#       2 new_df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:8206, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8204 else:
#    8205     index = missing.get_interp_index(method, obj.index)
# -> 8206     new_data = obj._mgr.interpolate(
#    8207         method=method,
#    8208         index=index,
#    8209         limit=limit,
#    8210         limit_direction=limit_direction,
# ...

# %%
x
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x.dropna(how='all')
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x.dropna()
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x.dropna(thresh=2)
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/7/2017          32.0        NaN    Rain
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
x
# Out:
#            temperature  windspeed   event
# day
# 1/1/2017          32.0        6.0    Rain
# 1/4/2017           NaN        9.0   Sunny
# 1/5/2017          28.0        NaN    Snow
# 1/6/2017           NaN        7.0     NaN
# 1/7/2017          32.0        NaN    Rain
# 1/8/2017           NaN        NaN   Sunny
# 1/9/2017           NaN        NaN     NaN
# 1/10/2017         34.0        8.0  Cloudy
# 1/11/2017         40.0       12.0   Sunny

# %%
y=pd.date_range('1/1/2017','1/11/2017')

# %%
y
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
z=pd.DataFrame(y)

# %%
z
# Out:
#             0
# 0  2017-01-01
# 1  2017-01-02
# 2  2017-01-03
# 3  2017-01-04
# 4  2017-01-05
# 5  2017-01-06
# 6  2017-01-07
# 7  2017-01-08
# 8  2017-01-09
# 9  2017-01-10
# 10 2017-01-11

# %%
x.reindex(z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:560, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     559 try:
# --> 560     arr = sanitize_array(data, None, dtype=dtype, copy=copy)
#     561 except ValueError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\construction.py:658, in sanitize_array(data, index, dtype, copy, allow_2d)
#     656             subarr = maybe_infer_to_datetimelike(subarr)
# --> 658 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     660 if isinstance(subarr, np.ndarray):
#     661     # at this point we should have dtype be None or subarr.dtype == dtype
#
# File ~\anaconda3\Lib\site-packages\pandas\core\construction.py:717, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     716         return result
# ...

# %%
x.shape
# Out:
# (9, 3)

# %%
x.reindex(y)
# Out:
#             day  temperature  windspeed event
# 2017-01-01  NaN          NaN        NaN   NaN
# 2017-01-02  NaN          NaN        NaN   NaN
# 2017-01-03  NaN          NaN        NaN   NaN
# 2017-01-04  NaN          NaN        NaN   NaN
# 2017-01-05  NaN          NaN        NaN   NaN
# 2017-01-06  NaN          NaN        NaN   NaN
# 2017-01-07  NaN          NaN        NaN   NaN
# 2017-01-08  NaN          NaN        NaN   NaN
# 2017-01-09  NaN          NaN        NaN   NaN
# 2017-01-10  NaN          NaN        NaN   NaN
# 2017-01-11  NaN          NaN        NaN   NaN

# %%
x.reset_index(inplace=True)

# %%
x
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
x=pd.read_csv('C:\\Users\\barad\\Downloads\\weather_data (1).csv')

# %%
x.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain

# %%
x.replace(-99999,np.nan)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
import numpy as np

# %%
x.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain

# %%
x.replace(to_replace=[-99999,-88888,'0'],value=1)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017            1          7  Sunny
# 2  1/3/2017           28          1   Snow
# 3  1/4/2017            1          7      1
# 4  1/5/2017           32          1   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      1

# %%
x
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
x.replace({'temperature':-99999,'windspeed':-99999,'event':'0'},'Kali_Maa_Sai')
# Out:
#         day   temperature     windspeed         event
# 0  1/1/2017            32             6          Rain
# 1  1/2/2017  Kali_Maa_Sai             7         Sunny
# 2  1/3/2017            28  Kali_Maa_Sai          Snow
# 3  1/4/2017  Kali_Maa_Sai             7  Kali_Maa_Sai
# 4  1/5/2017            32  Kali_Maa_Sai          Rain
# 5  1/6/2017            31             2         Sunny
# 6  1/6/2017            34             5  Kali_Maa_Sai

# %%
x
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
x.replace({-99999:np.nan,'0':'No Event'})
# Out:
#         day  temperature  windspeed     event
# 0  1/1/2017         32.0        6.0      Rain
# 1  1/2/2017          NaN        7.0     Sunny
# 2  1/3/2017         28.0        NaN      Snow
# 3  1/4/2017          NaN        7.0  No Event
# 4  1/5/2017         32.0        NaN      Rain
# 5  1/6/2017         31.0        2.0     Sunny
# 6  1/6/2017         34.0        5.0  No Event

# %%
x
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
x.replace({'event':'[A-Za-z]'},x.dropna,regex=True,inplace=True)

# %%
x.head()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
# ...

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
print("Jai Maa Kali")
# Out:
# Jai Maa Kali

# %%
import pandas as pd

# %%
x=pd.read_csv('C:\\Users\\barad\\Downloads\\weather_by_cities.csv')

# %%
x.head()
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# 4  1/1/2017    mumbai           90          5  Sunny

# %%
 #What was the maximum temperature in each of these 3 cities?
x.groupby('city').max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
x
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
x
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
z=x.groupby('city')

# %%
z

# %%
for city,city_df in z:
    print(city_df)
    print(city)
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# mumbai
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# new york
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy
# paris

# %%
z.min()
# Out:
#                day  temperature  windspeed   event
# city
# mumbai    1/1/2017           85          5     Fog
# new york  1/1/2017           28          6    Rain
# paris     1/1/2017           42          8  Cloudy

# %%
z.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
z.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# ...

# %%
z.get_group('new york')
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
z.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
z.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# ...

# %%
z.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
z.count()
# Out:
#           day  temperature  windspeed  event
# city
# mumbai      4            4          4      4
# new york    4            4          4      4
# paris       4            4          4      4

# %%
x
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
z.agg(lambda x:np.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 z.agg(lambda x:np.mean())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1495, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1493 gba = GroupByApply(self, [func], args=(), kwargs={})
#    1494 try:
# -> 1495     result = gba.agg()
#    1497 except ValueError as err:
#    1498     if "No objects to concatenate" not in str(err):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:178, in Apply.agg(self)
#     175     return self.agg_dict_like()
#     176 elif is_list_like(func):
#     177     # we require a list, but not a 'str'
# --> 178     return self.agg_list_like()
#     180 if callable(func):
#     181     f = com.get_cython_func(func)
#
# ...

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
z.plot()
# Out:
# city
# mumbai      Axes(0.125,0.11;0.775x0.77)
# new york    Axes(0.125,0.11;0.775x0.77)
# paris       Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
def fun(n):
    return x(lambda x : n+2*3)

# %%
x = lambda a : a + 10
print(x(5))
# Out:
# 15

# %%
x=pd.DataFrame({"city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]})

# %%
import pandas as pd

# %%
y=pd.DataFrame({"city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]})

# %%
x,y
# Out:
# (       city  temperature  humidity
#  0    mumbai           32        80
#  1     delhi           45        60
#  2  banglore           30        78,
#         city  temperature  humidity
#  0  new york           21        68
#  1   chicago           14        65
#  2   orlando           35        75)

# %%
z=pd.concat([x,y],ignore_index=False,keys=['INDIA','USA'])

# %%
z
# Out:
#              city  temperature  humidity
# INDIA 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# USA   0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
z
# Out:
#              city  temperature  humidity
# INDIA 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# USA   0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
z.loc['INDIA']
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
z.loc['USA']
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
x=pd.DataFrame({ "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30]},index=[0,1,2])

# %%
x
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
y=pd.DataFrame({"city": ["delhi","mumbai"],
    "windspeed": [7,12]},index=[0,1])

# %%
t=pd.concat([x,y],axis=1)

# %%
c=pd.Series(["Humid","Dry","Rain"],name='event')

# %%
pd.concat([t,c],axis=1)
# Out:
#        city  temperature    city  windspeed  event
# 0    mumbai           32   delhi        7.0  Humid
# 1     delhi           45  mumbai       12.0    Dry
# 2  banglore           30     NaN        NaN   Rain

# %%
print("Jai Maa Kali")
# Out:
# Jai Maa Kali

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Jai Maa Kali")
# Out:
# Jai Maa Kali

# %%
import pandas as pd

# %%
x=pd.DataFrame({"city": ["new york","chicago","orlando"],
    "temperature": [21,14,35]})

# %%
x
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
y=pd.DataFrame({"city": ["chicago","new york","orlando"],
    "humidity": [65,68,75]})

# %%
y
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
z=pd.merge(x,y,on='city',how='outer')

# %%
z
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
pd.merge(df1,df2,on='city',indicator=True,how='outer')
# Out:
#         city  temperature  humidity      _merge
# 0   new york         21.0      68.0        both
# 1    chicago         14.0      65.0        both
# 2    orlando         35.0       NaN   left_only
# 3  baltimore         38.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
df1.join(df2,on='city',how='outer',lsuffix='l',rsuffix='r')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df1.join(df2,on='city',how='outer',lsuffix='l',rsuffix='r')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10412, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10402     if how == "cross":
#   10403         return merge(
#   10404             self,
#   10405             other,
#    (...)
#   10410             validate=validate,
#   10411         )
# > 10412     return merge(
#   10413         self,
#   10414         other,
#   10415         left_on=on,
#   10416         how=how,
#   10417         left_index=on is None,
#   10418         right_index=True,
#   10419         suffixes=(lsuffix, rsuffix),
#   10420         sort=sort,
#   10421         validate=validate,
#   10422     )
#   10423 else:
#   10424     if on is not None:
#
# ...

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1.set_index('city',inplace=True)

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2.set_index('city',inplace=True)

# %%
df2
# Out:
#           humidity
# city
# chicago         65
# new york        68
# orlando         75

# %%
df1.join(df2,lsuffix='l',rsuffix='r')
# Out:
#           temperature  humidity
# city
# new york           21        68
# chicago            14        65
# orlando            35        75

# %%
import numpy as np

# %%
import pandas as pd
import numpy as np

# %%
x= pd.read_csv("weather.csv")

# %%
x
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
x.pivot(index='date',columns='city',values='temperature')
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       80      75        65
# 5/2/2017       77      78        66
# 5/3/2017       79      82        68

# %%
#x.pivot(index='',columns='',values='')
df = pd.read_csv("weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
type(df['date'][0])
# Out:
# str

# %%
df.pivot_table(index='city',columns='date',aggfunc=np.mean,margins=True)
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_12908\2488983236.py:1: FutureWarning: The provided callable <function mean at 0x000001674D105E40> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(index='city',columns='date',aggfunc=np.mean,margins=True)
# C:\Users\barad\AppData\Local\Temp\ipykernel_12908\2488983236.py:1: FutureWarning: The provided callable <function mean at 0x000001674D105E40> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(index='city',columns='date',aggfunc=np.mean,margins=True)
# ...

# %%
65+61
# Out:
# 126

# %%
126/2
# Out:
# 63.0

# %%
#Grouper

# %%
df = pd.read_csv("weather3.csv")
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
df['date']=pd.to_datetime(df['date'])

# %%
type(df['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city',aggfunc=np.sum)
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_12908\4221022255.py:1: FutureWarning: The provided callable <function sum at 0x000001674D1047C0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city',aggfunc=np.sum)
#            humidity temperature
# city       new york    new york
# date
# 2017-05-31      170         196
# 2017-12-31      153          83

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city',values='temperature')
# Out:
# city         new york
# date
# 2017-05-31  65.333333
# 2017-12-31  27.666667

# %%
x=pd.read_csv('weather (1).csv')

# %%
x
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
t=pd.melt(x,id_vars=['day'],var_name='city',value_name='temperature')

# %%
t
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %%
t[t['city']=='berlin']
# Out:
#           day    city  temperature
# 14     Monday  berlin           41
# 15    Tuesday  berlin           43
# 16  Wednesday  berlin           45
# 17   Thursday  berlin           38
# 18     Friday  berlin           30
# 19   Saturday  berlin           45
# 20     Sunday  berlin           47

# %%
x
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
#melt is used for transformation

# %%
x=pd.read_excel('stocks.xlsx',header=[0,1])

# %%
x.stack(level=0,dropna=True)
# Out:
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
#   Unnamed: 0_level_0            2017-06-07       NaN     NaN        NaN
# 3 Price                                NaT    155.00  1000.0      61.00
#   Price to earnings ratio (P/E)        NaT     36.11    31.2      30.11
#   Unnamed: 0_level_0            2017-06-08       NaN     NaN        NaN
# ...

# %%
y
# Out:
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
#   Unnamed: 0_level_0            2017-06-07       NaN     NaN        NaN
# 3 Price                                NaT    155.00  1000.0      61.00
#   Price to earnings ratio (P/E)        NaT     36.11    31.2      30.11
#   Unnamed: 0_level_0            2017-06-08       NaN     NaN        NaN
# ...

# %%
y.stack()
# Out:
# 0  Price                          Facebook                   155.0
#                                   Google                     955.0
#                                   Microsoft                   66.0
#    Price to earnings ratio (P/E)  Facebook                    37.1
#                                   Google                      32.0
#                                   Microsoft                  30.31
#    Unnamed: 0_level_0             Company      2017-06-05 00:00:00
# 1  Price                          Facebook                   150.0
#                                   Google                     987.0
#                                   Microsoft                   69.0
#    Price to earnings ratio (P/E)  Facebook                   36.98
#                                   Google                      31.3
#                                   Microsoft                  30.56
#    Unnamed: 0_level_0             Company      2017-06-06 00:00:00
# ...

# %%
x=pd.read_excel('survey.xls')

# %%
pip install xlrd
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
x
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(x.Nationality,x.Handedness,margins=True)
# Out:
# Handedness   Left  Right  All
# Nationality
# Bangadesh       2      0    2
# China           2      1    3
# India           2      1    3
# USA             1      3    4
# All             7      5   12

# %%
pd.crosstab([x.Nationality,x.Handedness],x.Sex,margins=True)
# Out:
# Sex                     Female  Male  All
# Nationality Handedness
# Bangadesh   Left             1     1    2
# China       Left             1     1    2
#             Right            1     0    1
# India       Left             0     2    2
#             Right            0     1    1
# USA         Left             0     1    1
#             Right            2     1    3
# All                          5     7   12

# %%
pd.crosstab(x.Sex,x.Handedness,values=x.Age,aggfunc=np.median)
# Out:
# C:\Users\barad\AppData\Local\Temp\ipykernel_12908\3120969822.py:1: FutureWarning: The provided callable <function median at 0x000001674D252E80> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   pd.crosstab(x.Sex,x.Handedness,values=x.Age,aggfunc=np.median)
# Handedness  Left  Right
# Sex
# Female      44.5   23.0
# Male        31.0   28.0

# %%
pip install PyMySQL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy

# %%
#engine = sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/application')

# %%
#pd.read_sql_table('customers',engine)

# %%
query=''

# %%
#pd.read_sql_query(query,engine)
#pd.read_sql()#we can supply table as well as query for table use
#pd.read_sql_table
#for Query use below one
#pd.read_sql_query

# %%
#writing from python to SQL Database
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
df.rename(columns={'temperature':'temp','humidity':'humid'},inplace=True)

# %%
df
# Out:
#         date      city  temp  humid
# 0 2017-05-01  new york    65     56
# 1 2017-05-02  new york    61     54
# 2 2017-05-03  new york    70     60
# 3 2017-12-01  new york    30     50
# 4 2017-12-02  new york    28     52
# 5 2017-12-03  new york    25     51

# %%
#df.to_sql(name='name of the table',con=engine,if_exists='append',index=False)
